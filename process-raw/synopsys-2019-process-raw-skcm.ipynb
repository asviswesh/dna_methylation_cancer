# %%
import pandas as pd
import os

# %%
#########################
# Test
#########################
df = pd.read_csv("/Users/annika/annika/high-school/cs/tgca-downloads/SKCM/c7fd4ee7-371a-4db4-86ce-2d6a703d29b5/jhu-usc.edu_SKCM.HumanMethylation450.1.lvl-3.TCGA-FS-A1ZW-06A-12D-A19C-05.gdc_hg38.txt", sep = "\t")
df.sort_values(by='Composite Element REF', inplace=True)
df.head(5)
# Out:
#   Composite Element REF  Beta_value Chromosome      Start        End  \
# 0            cg00000029    0.481716      chr16   53434200   53434201
# 1            cg00000108         NaN       chr3   37417715   37417716
# 2            cg00000109         NaN       chr3  172198247  172198248
# 3            cg00000165    0.635898       chr1   90729117   90729118
# 4            cg00000236    0.915510       chr8   42405776   42405777
#
#                                          Gene_Symbol  \
# 0                                     RBL2;RBL2;RBL2
# 1  C3orf35;C3orf35;C3orf35;C3orf35;C3orf35;C3orf3...
# 2          FNDC3B;FNDC3B;FNDC3B;FNDC3B;FNDC3B;FNDC3B
# 3                                                  .
# 4                                              VDAC3
#
#                                            Gene_Type  \
# 0       protein_coding;protein_coding;protein_coding
# 1  lincRNA;lincRNA;lincRNA;lincRNA;lincRNA;lincRN...
# 2  protein_coding;protein_coding;protein_coding;p...
# 3                                                  .
# 4                                     protein_coding
#
#                                        Transcript_ID  \
# 0  ENST00000262133.9;ENST00000544405.5;ENST000005...
# 1  ENST00000328376.8;ENST00000332506.6;ENST000004...
# 2  ENST00000336824.7;ENST00000415807.5;ENST000004...
# 3                                                  .
# 4                                  ENST00000022615.7
#
#                                 Position_to_TSS                CGI_Coordinate  \
# 0                                -221;-1420;222   CGI:chr16:53434489-53435297
# 1  18552;18552;6505;31445;18143;447;18552;18552    CGI:chr3:37451927-37453047
# 2       157692;158618;151333;71272;158587;71273  CGI:chr3:172039703-172040934
# 3                                             .    CGI:chr1:90724932-90727247
# 4                                         13872    CGI:chr8:42410918-42411241
#
#   Feature_Type
# 0      N_Shore
# 1            .
# 2            .
# 3      S_Shore
# 4            .

# %%
#########################
# Test
#########################
#Imputation by mean values to fill up missing values
df['Beta_value'].fillna(df['Beta_value'].mean(),inplace=True) 
df.head(5)
# Out:
#   Composite Element REF  Beta_value Chromosome      Start        End  \
# 0            cg00000029    0.481716      chr16   53434200   53434201
# 1            cg00000108    0.400710       chr3   37417715   37417716
# 2            cg00000109    0.400710       chr3  172198247  172198248
# 3            cg00000165    0.635898       chr1   90729117   90729118
# 4            cg00000236    0.915510       chr8   42405776   42405777
#
#                                          Gene_Symbol  \
# 0                                     RBL2;RBL2;RBL2
# 1  C3orf35;C3orf35;C3orf35;C3orf35;C3orf35;C3orf3...
# 2          FNDC3B;FNDC3B;FNDC3B;FNDC3B;FNDC3B;FNDC3B
# 3                                                  .
# 4                                              VDAC3
#
#                                            Gene_Type  \
# 0       protein_coding;protein_coding;protein_coding
# 1  lincRNA;lincRNA;lincRNA;lincRNA;lincRNA;lincRN...
# 2  protein_coding;protein_coding;protein_coding;p...
# 3                                                  .
# 4                                     protein_coding
#
#                                        Transcript_ID  \
# 0  ENST00000262133.9;ENST00000544405.5;ENST000005...
# 1  ENST00000328376.8;ENST00000332506.6;ENST000004...
# 2  ENST00000336824.7;ENST00000415807.5;ENST000004...
# 3                                                  .
# 4                                  ENST00000022615.7
#
#                                 Position_to_TSS                CGI_Coordinate  \
# 0                                -221;-1420;222   CGI:chr16:53434489-53435297
# 1  18552;18552;6505;31445;18143;447;18552;18552    CGI:chr3:37451927-37453047
# 2       157692;158618;151333;71272;158587;71273  CGI:chr3:172039703-172040934
# 3                                             .    CGI:chr1:90724932-90727247
# 4                                         13872    CGI:chr8:42410918-42411241
#
#   Feature_Type
# 0      N_Shore
# 1            .
# 2            .
# 3      S_Shore
# 4            .

# %%
#########################
# Test
#########################
#transpose the rows and columns
df_transposed = df.T
df_transposed.head(5)
# Out:
#                            0           1           2           3       \
# Composite Element REF  cg00000029  cg00000108  cg00000109  cg00000165
# Beta_value               0.481716     0.40071     0.40071    0.635898
# Chromosome                  chr16        chr3        chr3        chr1
# Start                    53434200    37417715   172198247    90729117
# End                      53434201    37417716   172198248    90729118
#
#                            4           5           6           7       \
# Composite Element REF  cg00000236  cg00000289  cg00000292  cg00000321
# Beta_value                0.91551    0.749313    0.793684     0.67504
# Chromosome                   chr8       chr14       chr16        chr8
# Start                    42405776    68874422    28878779    41310283
# End                      42405777    68874423    28878780    41310284
#
#                            8           9         ...         485567  \
# Composite Element REF  cg00000363  cg00000622    ...      rs7746156
# Beta_value               0.619806   0.0109503    ...        0.45672
# Chromosome                   chr1       chr15    ...           chr6
# Start                   230425047    22838620    ...       47163083
# End                     230425048    22838621    ...       47163083
#
#                           485568     485569     485570     485571     485572  \
# Composite Element REF   rs798149   rs845016   rs877309  rs9292570  rs9363764
# Beta_value             0.0139622  0.0320526  0.0177213   0.962484   0.952218
# Chromosome                  chrX      chr21       chr1       chr5       chr6
# Start                   15867308   32625974   11429621   35000207   67522149
# End                     15867308   32625974   11429621   35000207   67522149
#
#                          485573     485574    485575     485576
# Composite Element REF  rs939290   rs951295  rs966367  rs9839873
# Beta_value              0.53036  0.0473267  0.948374   0.961511
# Chromosome                 chr3      chr15      chr2       chr3
# Start                  14617359   45707625  12008094   86613005
# End                    14617359   45707625  12008094   86613005
#
# [5 rows x 485577 columns]

# %%
#########################
# Test
#########################
# Create a new variable called 'header' from the first row of the dataset
df_headers = df_transposed.iloc[0] 
df_headers.head(5)
# Out:
# 0    cg00000029
# 1    cg00000108
# 2    cg00000109
# 3    cg00000165
# 4    cg00000236
# Name: Composite Element REF, dtype: object

# %%
#########################
# Test
#########################
# Replace the dataframe with a new one which does not contain the first row
df_transposed = df_transposed[1:2]
df_transposed.head(5)
# Out:
#               0        1        2         3        4         5         6       \
# Beta_value  0.481716  0.40071  0.40071  0.635898  0.91551  0.749313  0.793684
#
#              7         8          9         ...      485567     485568  \
# Beta_value  0.67504  0.619806  0.0109503    ...     0.45672  0.0139622
#
#                485569     485570    485571    485572   485573     485574  \
# Beta_value  0.0320526  0.0177213  0.962484  0.952218  0.53036  0.0473267
#
#               485575    485576
# Beta_value  0.948374  0.961511
#
# [1 rows x 485577 columns]

# %%
#########################
# Test
#########################
# Rename the dataframe's column values with the header variable
df_transposed.rename(columns = df_headers, inplace=True)
df_transposed.head(5)
# Out:
#            cg00000029 cg00000108 cg00000109 cg00000165 cg00000236 cg00000289  \
# Beta_value   0.481716    0.40071    0.40071   0.635898    0.91551   0.749313
#
#            cg00000292 cg00000321 cg00000363 cg00000622    ...    rs7746156  \
# Beta_value   0.793684    0.67504   0.619806  0.0109503    ...      0.45672
#
#              rs798149   rs845016   rs877309 rs9292570 rs9363764 rs939290  \
# Beta_value  0.0139622  0.0320526  0.0177213  0.962484  0.952218  0.53036
#
#              rs951295  rs966367 rs9839873
# Beta_value  0.0473267  0.948374  0.961511
#
# [1 rows x 485577 columns]

# %%
#########################
# Test
#########################
#Add a column with cancerType to the end of the data frame
df_transposed = df_transposed.assign(CancerType='SKCM')
df_transposed.head(5) #scroll to the end to see the new column 'CancerType'
# Out:
#            cg00000029 cg00000108 cg00000109 cg00000165 cg00000236 cg00000289  \
# Beta_value   0.481716    0.40071    0.40071   0.635898    0.91551   0.749313
#
#            cg00000292 cg00000321 cg00000363 cg00000622    ...       rs798149  \
# Beta_value   0.793684    0.67504   0.619806  0.0109503    ...      0.0139622
#
#              rs845016   rs877309 rs9292570 rs9363764 rs939290   rs951295  \
# Beta_value  0.0320526  0.0177213  0.962484  0.952218  0.53036  0.0473267
#
#             rs966367 rs9839873 CancerType
# Beta_value  0.948374  0.961511       SKCM
#
# [1 rows x 485578 columns]

# %%
#########################
# Test
#########################
#Read the next file
df2 = pd.read_csv("/Users/annika/annika/high-school/cs/tgca-downloads/SKCM/85adf7bb-8ad3-4e4b-bf8d-f3f2684ad05d/jhu-usc.edu_SKCM.HumanMethylation450.10.lvl-3.TCGA-RP-A6K9-06A-41D-A34V-05.gdc_hg38.txt", sep = "\t")
#Sort by the column which has the 'Composite Element REF'
df2.sort_values(by='Composite Element REF', inplace=True)
#Imputation by mean values to fill up missing values
df2['Beta_value'].fillna(df2['Beta_value'].mean(),inplace=True) 
#transpose the rows and columns
df2_transposed = df2.T
# Create a new variable called 'header' from the first row of the dataset
df2_headers = df2_transposed.iloc[0] 
# Replace the dataframe with a new one which does not contain the first row
df2_transposed = df2_transposed[1:2]
# Rename the dataframe's column values with the header variable
df2_transposed.rename(columns = df2_headers, inplace=True)
df2_transposed = df2_transposed.assign(CancerType='SKCM')
df2_transposed.head()
# Out:
#            cg00000029 cg00000108 cg00000109 cg00000165 cg00000236 cg00000289  \
# Beta_value   0.651825   0.471031   0.471031   0.530507   0.921265   0.742232
#
#            cg00000292 cg00000321 cg00000363 cg00000622    ...      rs798149  \
# Beta_value   0.721557   0.609868    0.71018  0.0151704    ...      0.367136
#
#            rs845016   rs877309 rs9292570 rs9363764  rs939290  rs951295  \
# Beta_value   0.9361  0.0133873  0.972289  0.315858  0.339031  0.971593
#
#              rs966367 rs9839873 CancerType
# Beta_value  0.0280256  0.867921       SKCM
#
# [1 rows x 485578 columns]

# %%
#########################
# Test
#########################
#concat the dataframes from the 2 files
dflist2 = [df_transposed]
dflist2.append(df2_transposed)
dfFinal2 = pd.concat(dflist2)
dfFinal2.head(5)
# Out:
#            cg00000029 cg00000108 cg00000109 cg00000165 cg00000236 cg00000289  \
# Beta_value   0.481716    0.40071    0.40071   0.635898    0.91551   0.749313
# Beta_value   0.651825   0.471031   0.471031   0.530507   0.921265   0.742232
#
#            cg00000292 cg00000321 cg00000363 cg00000622    ...       rs798149  \
# Beta_value   0.793684    0.67504   0.619806  0.0109503    ...      0.0139622
# Beta_value   0.721557   0.609868    0.71018  0.0151704    ...       0.367136
#
#              rs845016   rs877309 rs9292570 rs9363764  rs939290   rs951295  \
# Beta_value  0.0320526  0.0177213  0.962484  0.952218   0.53036  0.0473267
# Beta_value     0.9361  0.0133873  0.972289  0.315858  0.339031   0.971593
#
#              rs966367 rs9839873 CancerType
# Beta_value   0.948374  0.961511       SKCM
# Beta_value  0.0280256  0.867921       SKCM
#
# [2 rows x 485578 columns]

# %%
#########################
# Test
#########################
# Save to csv file
filename = "SKCM_betaValuesTesting2.csv"
dfFinal2.to_csv(filename,  index = False) # Do not save the index

# %%
#########################
# Test
#########################
#read from csv file in chunks
#filename = "LUAD_betaValuesTesting2.csv"
dfFrameList = []
for chunkTemp in pd.read_csv(filename, chunksize=1):
    dfFrameList.append(chunkTemp)
dataFrame = pd.concat(dfFrameList)        
dataFrame.head(5)
# Out:
#    cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  cg00000289  \
# 0    0.481716    0.400710    0.400710    0.635898    0.915510    0.749313
# 1    0.651825    0.471031    0.471031    0.530507    0.921265    0.742232
#
#    cg00000292  cg00000321  cg00000363  cg00000622     ...      rs798149  \
# 0    0.793684    0.675040    0.619806     0.01095     ...      0.013962
# 1    0.721557    0.609868    0.710180     0.01517     ...      0.367136
#
#    rs845016  rs877309  rs9292570  rs9363764  rs939290  rs951295  rs966367  \
# 0  0.032053  0.017721   0.962484   0.952218  0.530360  0.047327  0.948374
# 1  0.936100  0.013387   0.972289   0.315858  0.339031  0.971593  0.028026
#
#    rs9839873  CancerType
# 0   0.961511        SKCM
# 1   0.867921        SKCM
#
# [2 rows x 485578 columns]

# %%
#########################
# Program to preprocess all raw files for a cancer type
#########################
import pandas as pd
import os
import glob # Use glob to read files with wildcards

# Location for LUAD files
#For all files use this path
path = "/Users/annika/annika/high-school/cs/tgca-downloads/SKCM/*/*n450*.*txt"

# Get the list of files
dirList = glob.glob(path)
# Initialize a list
dflist = []
for d in dirList:
    # Read the next file
    df3 = pd.read_csv(d, sep = "\t")
    # Sort by the column which has the 'Composite Element REF' so that 
    # the methalyation sites are sorted
    df3.sort_values(by='Composite Element REF', inplace=True)
    # Imputation by mean values to fill up missing values
    df3['Beta_value'].fillna(df3['Beta_value'].mean(),inplace=True) 
    # Transpose the rows and columns, so that all beta values are in a row
    df3_transposed = df3.T
    # Create a new variable called 'header' from the first row of the dataset which are
    # the values of 'Composite Element REF' e.g. cg00000029
    df3_headers = df3_transposed.iloc[0] 
    # Replace the dataframe with a new one which only contains the beta values
    df3_transposed = df3_transposed[1:2]
    # Rename the dataframe's column names with the header variable i.e. 
    # 'Composite Element REF' e.g. cg00000029
    df3_transposed.rename(columns = df3_headers, inplace=True)
    # Create a new column with the column name as 'CancerType' and value as 'LUAD'
    df3_transposed = df3_transposed.assign(CancerType='SKCM')
    # concat the dataframes into a list
    dflist.append(df3_transposed)
# Convert the list to a dataframe    
dfFinal = pd.concat(dflist)
# Save the dataframe to csv file, do not save the index
dfFinal.to_csv("../../data/SKCM/SKCM_betaValuesOnly.csv", index = False) 
# Now the raw files can be deleted and only the csv files can be retained.

# %%
#dfFinal.to_csv("../../data/LUAD/LUAD_betaValuesOnly.csv", index = False) 
# Now the raw files can be deleted and only the csv files can be retained.

# %%
#########################
# Test
#########################
dfFinal.head(10)
# Out:
#            cg00000029 cg00000108 cg00000109 cg00000165 cg00000236 cg00000289  \
# Beta_value   0.653875   0.462084   0.462084   0.188038   0.929934   0.557059
# Beta_value   0.797287   0.506021   0.506021   0.796145   0.917371   0.745327
# Beta_value   0.450192   0.455224   0.455224   0.520731   0.889092   0.599019
# Beta_value   0.225955   0.449492   0.449492    0.58054   0.875329   0.632558
# Beta_value    0.32856    0.44648    0.44648    0.74917   0.927151   0.787465
# Beta_value   0.658063   0.454027   0.454027   0.560587   0.888787   0.662061
# Beta_value   0.238704    0.42296    0.42296   0.743041   0.871439   0.715144
# Beta_value   0.744926   0.505918   0.505918   0.387518   0.882199   0.623588
# Beta_value   0.295922   0.369932   0.369932    0.26057   0.829156   0.410695
# Beta_value   0.139619   0.374463   0.374463   0.626059   0.872941   0.773904
#
#            cg00000292 cg00000321 cg00000363 cg00000622    ...       rs798149  \
# Beta_value   0.811276   0.690235   0.680045  0.0129433    ...       0.974221
# Beta_value    0.85624   0.524419   0.722452  0.0139409    ...       0.970525
# Beta_value   0.679979   0.536189    0.52698  0.0132348    ...        0.34776
# Beta_value   0.659629    0.20585   0.601724  0.0121523    ...       0.972949
# Beta_value    0.85986   0.647849   0.621599   0.012473    ...       0.971984
# Beta_value   0.808517   0.435286   0.634731  0.0154875    ...       0.373248
# Beta_value   0.375804   0.681324    0.54363  0.0141791    ...       0.971684
# Beta_value   0.877309   0.408035   0.455206  0.0149277    ...       0.371667
# Beta_value   0.434008   0.204902   0.666908  0.0114759    ...       0.015235
# Beta_value   0.745176    0.76033   0.770108  0.0129782    ...      0.0124579
#
#              rs845016   rs877309 rs9292570  rs9363764   rs939290   rs951295  \
# Beta_value   0.739014  0.0138524  0.967595   0.318181   0.632453    0.31906
# Beta_value   0.934675  0.0132392  0.577659  0.0434082  0.0250022   0.349452
# Beta_value   0.926923   0.962697  0.966239   0.702347    0.71666   0.517483
# Beta_value  0.0346968  0.0143223  0.261664   0.777097   0.517319   0.527307
# Beta_value   0.937538    0.96953  0.564626   0.945186   0.553898   0.969658
# Beta_value   0.462474   0.557961  0.968225   0.959336   0.572572   0.545317
# Beta_value   0.919111   0.807435  0.505236    0.95448   0.971642   0.596453
# Beta_value   0.898011   0.522765  0.962029   0.536041   0.951242  0.0577037
# Beta_value  0.0469058   0.621343  0.482971   0.250819   0.546088   0.040901
# Beta_value   0.154494   0.511457  0.969497   0.886732   0.531829   0.530215
#
#              rs966367 rs9839873 CancerType
# Beta_value  0.0365882  0.962883       SKCM
# Beta_value   0.946547  0.942433       SKCM
# Beta_value   0.506573  0.936376       SKCM
# Beta_value    0.95259  0.739334       SKCM
# Beta_value   0.792988  0.492494       SKCM
# Beta_value   0.519867  0.949615       SKCM
# Beta_value    0.58433  0.954803       SKCM
# Beta_value   0.465089  0.891142       SKCM
# Beta_value   0.450222   0.91097       SKCM
# Beta_value    0.82664   0.95221       SKCM
#
# [10 rows x 485578 columns]

# %%
dfFinal.shape
# Out:
# (201, 485578)
