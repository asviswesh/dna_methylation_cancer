# %%
#########################
# Test
#########################
import pandas as pd
import os

#import fnmatch
#read from csv file
filename = "../../data/LUAD/LUAD_betaValuesOnly.csv"
dfFrameList = []
iteration = 1
for chunkTemp in pd.read_csv(filename, chunksize=2):
    #dataFrameTemp = pd.DataFrame(chunkTemp.get_chunk(20))
    #pd.concat([dataFrame, chunkTemp])
    dfFrameList.append(chunkTemp)
    iteration += 1
    if iteration > 2:
        break
dataFrame = pd.concat(dfFrameList) 
filename = "../../data/LGG/LGG_betaValuesOnly.csv"
dfFrameList2 = []
iteration = 1
for chunkTemp in pd.read_csv(filename, chunksize=2):
    #dataFrameTemp = pd.DataFrame(chunkTemp.get_chunk(20))
    #pd.concat([dataFrame, chunkTemp])
    dfFrameList2.append(chunkTemp)
    iteration += 1
    if iteration > 2:
        break
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-4ac6750a97d8> in <module>()
#      28     if iteration > 2:
#      29         break
# ---> 30 dataFrame.concat(pd.concat(dfFrameList2))
#      31 dataFrame.head(20)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
dataFrame = dataFrame.append(pd.concat(dfFrameList2), ignore_index= True)
dataFrame.head(20)
# Out:
#     cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  cg00000289  \
# 0     0.249354    0.518107    0.518107    0.513046    0.853204    0.705116
# 1     0.159052    0.417547    0.417547    0.198068    0.863080    0.593600
# 2     0.276347    0.470940    0.470940    0.563651    0.881473    0.697009
# 3     0.139515    0.472050    0.472050    0.378171    0.866939    0.701795
# 4     0.534983    0.472411    0.472411    0.161828    0.872788    0.548175
# 5     0.708750    0.474028    0.474028    0.452180    0.896702    0.618546
# 6     0.859662    0.540263    0.540263    0.220541    0.887298    0.687891
# 7     0.882891    0.535704    0.535704    0.752095    0.891607    0.705398
# 8     0.534983    0.472411    0.472411    0.161828    0.872788    0.548175
# 9     0.708750    0.474028    0.474028    0.452180    0.896702    0.618546
# 10    0.859662    0.540263    0.540263    0.220541    0.887298    0.687891
# ...

# %%
#########################
# Test
#########################
#import fnmatch
#read from csv file
# filename = "../data/LUAD_betaValuesOnly.csv"
# chunk = pd.read_csv(filename, chunksize=20)
# since we are not reading in a for loop have to use get_chunk to read from the TextReader
# df= pd.DataFrame(chunk.get_chunk(20))

# %%
#########################
# Program to load the preprocessed data from csv files
#########################
import pandas as pd
import os

#read from csv file in chunks as the file is too big 
filename = "../../data/LUAD/LUAD_betaValuesOnly.csv"
dfFrameList = []
for chunkTemp in pd.read_csv(filename, chunksize=20):
    dfFrameList.append(chunkTemp)
dataFrame = pd.concat(dfFrameList)        
dataFrame.head(20)
# Out:
#     cg00000029  cg00000108  cg00000109  cg00000165  cg00000236  cg00000289  \
# 0     0.249354    0.518107    0.518107    0.513046    0.853204    0.705116
# 1     0.159052    0.417547    0.417547    0.198068    0.863080    0.593600
# 2     0.276347    0.470940    0.470940    0.563651    0.881473    0.697009
# 3     0.139515    0.472050    0.472050    0.378171    0.866939    0.701795
# 4     0.212803    0.420617    0.420617    0.677257    0.757211    0.408809
# 5     0.080570    0.454083    0.454083    0.811211    0.914021    0.691389
# 6     0.307506    0.446609    0.446609    0.201405    0.803819    0.390484
# 7     0.477089    0.472587    0.472587    0.329425    0.840038    0.656121
# 8     0.088872    0.429825    0.429825    0.732556    0.908970    0.702688
# 9     0.170802    0.492869    0.492869    0.471985    0.841084    0.593019
# 10    0.200265    0.398324    0.398324    0.128996    0.893197    0.548238
# ...

# %%
#########################
# Test
#########################
#dataFrame.size
dataFrame.columns

# %%
#########################
# Test
#########################
#Should be done when creating the raw file, 
#column name should be 'Type" and 
#the value -'Beta_value' should be replaced by the type of cancer
#dataFrame.rename(columns={'Unnamed: 0':'Type'}, inplace = True)
#dataFrame.head(2)

# %%
#########################
# Test
#########################
# Reduce the dimensions using PCI

#from sklearn.model_selection import train_test_split
#https://towardsdatascience.com/pca-using-python-scikit-learn-e653f8989e60
# Out:
# pandas.core.frame.DataFrame

# %%
dataFrame.type

# %%
##########################################
#ROC Curve - DOES NOT WORK ... NEED TO DEBUG
##########################################
# from sklearn.metrics import roc_auc_score
# from sklearn.metrics import roc_curve
# logit_roc_auc = roc_auc_score(y_test, predictions)
# fpr, tpr, thresholds = roc_curve(y_test, logreg.predict_proba(X_test)[:,1])
# plt.figure()
# plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
# plt.plot([0, 1], [0, 1],'r--')
# plt.xlim([0.0, 1.0])
# plt.ylim([0.0, 1.05])
# plt.xlabel('False Positive Rate')
# plt.ylabel('True Positive Rate')
# plt.title('Receiver operating characteristic')
# plt.legend(loc="lower right")
# plt.savefig('Log_ROC')
# plt.show()
